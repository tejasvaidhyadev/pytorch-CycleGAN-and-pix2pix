# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-fb64540acb0c> in <module>()
# ----> 1 ls
#       2
#
# NameError: name 'ls' is not defined

# %%
list4renam = os.listdir("./train/")

# %%
list4renam
# Out:
# ['31834734_multi.png',
#  '31871448_multi.png',
#  '47464142_multi.png',
#  '31418847_multi.png',
#  '45175987_multi.png',
#  '47325578_multi.png',
#  '45741127_multi.png',
#  '45741076_multi.png',
#  '45724342_multi.png',
#  '31847853_multi.png',
#  '10_multi.png',
#  '2_multi.png',
#  '47360870_multi.png',
#  '31878867_multi.png',
#  '45783298_multi.png',
#  '47465963_multi.png',
#  '45724375_multi.png',
#  '45780376_multi.png',
#  '45724468_multi.png',
#  '42761030_multi.png',
#  '31483593_multi.png',
#  '31826949_multi.png',
#  '45756454_multi.png',
#  '47489621_multi.png',
#  '45724345_multi.png',
#  '45774964_multi.png',
#  '47464151_multi.png',
#  '45740521_multi.png',
#  '31814460_multi.png',
#  '30957516_multi.png',
#  '31874937_multi.png',
#  '45321949_multi.png',
#  '31852932_multi.png',
#  '50_multi.png',
#  '45743284_multi.png',
#  '44356523_multi.png',
#  '31857804_multi.png',
#  '31890228_multi.png',
#  '44591497_multi.png',
#  '45725026_multi.png',
# ...

# %%
des = []
for name in list4renam:
    spl = name.split("_")
    spl = spl[0]+".png"
    des.append(spl)

# %%
# Out:
# ['31834734.png',
#  '31871448.png',
#  '47464142.png',
#  '31418847.png',
#  '45175987.png',
#  '47325578.png',
#  '45741127.png',
#  '45741076.png',
#  '45724342.png',
#  '31847853.png',
#  '10.png',
#  '2.png',
#  '47360870.png',
#  '31878867.png',
#  '45783298.png',
#  '47465963.png',
#  '45724375.png',
#  '45780376.png',
#  '45724468.png',
#  '42761030.png',
#  '31483593.png',
#  '31826949.png',
#  '45756454.png',
#  '47489621.png',
#  '45724345.png',
#  '45774964.png',
#  '47464151.png',
#  '45740521.png',
#  '31814460.png',
#  '30957516.png',
#  '31874937.png',
#  '45321949.png',
#  '31852932.png',
#  '50.png',
#  '45743284.png',
#  '44356523.png',
#  '31857804.png',
#  '31890228.png',
#  '44591497.png',
#  '45725026.png',
#  '45724327.png',
#  '41459443.png',
#  '45613198.png',
#  '4.png',
#  '45.png',
#  '43169833.png',
#  '45765874.png',
#  '47514899.png',
#  '31882362.png',
#  '45775222.png',
#  '31820961.png',
#  '45720007.png',
#  '31878534.png',
#  '45763060.png',
# ...
